# %% [markdown]
# # 20211112
#
# 表示、统计、清晰、展示数据的能力
#
# Numpy: ndarray类型
#
# pyplot: Matplotlib
#
# Pandas: series, DataFrame
#
# 实例1： 图像的手绘效果
#
# 实例2： 引力波绘制
#
# 实例3： 房价趋势的关联因素分析
#
# 实例4： 股票数据的趋势分析曲线

# %%
a = 3

# %%
# 某个变量的相关信息

a?

# %%
# IPython的魔术命令
# %magic

# 例如
# %reset # 删除当前空间中的所有变量和名称
# %hist # IPython命令的输入历史
# %who # 显示当前命名空间中已经定义的变量
# %time statement # 给出代码的执行时间，statement代表一段代码
# %timeit statement # 多次执行代码，计算综合平均执行时间

# %%
import numpy as np

a = np.random.randn(1000,1000)

# %%
# %timeit np.dot(a,a)
# Out:
# 10 loops, best of 5: 65.5 ms per loop

# %%
# %who
# Out:
# a	 np

# %%
# %hist
# Out:
# a = 3
# a = 3
# a?
# %magic
# %magic
# import numpy as np
#
# a = np.random.randn(1000,1000)
# import numpy as np
#
# a = np.random.randn(1000,1000)
# %timeit np.dot(a,a)
# %who
# %hist
